# %%
import pandas as pd
import numpy as np

# %%
docA = "good boy"
docB = "good girl"
docC = "boy girl good"

# %%
corpus = [docA,docB,docC]
corpus
# Out:
# ['good boy', 'good girl', 'boy girl good']

# %%
words_set = set()

for doc in  corpus:
    words = doc.split(' ')
    words_set = words_set.union(set(words))
    
print('Number of words in the corpus:',len(words_set))
print('The words in the corpus: \n', words_set)
# Out:
# Number of words in the corpus: 3
# The words in the corpus:
#  {'boy', 'girl', 'good'}

# %%
n_docs = len(corpus)         #·Number of documents in the corpus
n_words_set = len(words_set) #·Number of unique words in the 

df_tf = pd.DataFrame(np.zeros((n_docs, n_words_set)), columns=words_set)

# Compute Term Frequency (TF)
for i in range(n_docs):
    words = corpus[i].split(' ') # Words in the document
    for w in words:
        df_tf[w][i] = df_tf[w][i] + (1 / len(words))
        
df_tf
# Out:
#         boy      girl      good
# 0  0.500000  0.000000  0.500000
# 1  0.000000  0.500000  0.500000
# 2  0.333333  0.333333  0.333333

# %%
print("IDF of: ")

idf = {}

for w in words_set:
    k = 0    # number of documents in the corpus that contain this word
    
    for i in range(n_docs):
        if w in corpus[i].split():
            k += 1
            
    idf[w] =  np.log10(n_docs / k)
    
    print(f'{w:>15}: {idf[w]:>10}' )
# Out:
# IDF of:
#             boy: 1.1760912590556813
#            girl: 1.1760912590556813
#            good:        1.0

# %%
df_tf_idf = df_tf.copy()

for w in words_set:
    for i in range(n_docs):
        df_tf_idf[w][i] = df_tf[w][i] * idf[w]
        
df_tf_idf
# Out:
#         boy      girl      good
# 0  0.588046  0.000000  0.500000
# 1  0.000000  0.588046  0.500000
# 2  0.392030  0.392030  0.333333
